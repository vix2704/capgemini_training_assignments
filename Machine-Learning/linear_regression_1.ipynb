# %% [markdown]
# <a href="https://colab.research.google.com/github/vix2704/capgemini_training_assignments/blob/main/Machine-Learning/linear_regression_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# linear regression using fetch_california_dataset

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
data = fetch_california_housing()
data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
df=pd.DataFrame(data.data, columns=data.feature_names)
df.head(10)
# Out:
#    MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127  ...  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137  ...  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136  ...  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352  ...  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853  ...  2.181467     37.85    -122.25
# 5  4.0368      52.0  4.761658  ...  2.139896     37.85    -122.25
# 6  3.6591      52.0  4.931907  ...  2.128405     37.84    -122.25
# 7  3.1200      52.0  4.797527  ...  1.788253     37.84    -122.25
# 8  2.0804      42.0  4.294118  ...  2.026891     37.84    -122.26
# 9  3.6912      52.0  4.970588  ...  2.172269     37.84    -122.25
#
# [10 rows x 8 columns]

# %%
df['price']=data.target
df
# Out:
#        MedInc  HouseAge  AveRooms  ...  Latitude  Longitude  price
# 0      8.3252      41.0  6.984127  ...     37.88    -122.23  4.526
# 1      8.3014      21.0  6.238137  ...     37.86    -122.22  3.585
# 2      7.2574      52.0  8.288136  ...     37.85    -122.24  3.521
# 3      5.6431      52.0  5.817352  ...     37.85    -122.25  3.413
# 4      3.8462      52.0  6.281853  ...     37.85    -122.25  3.422
# ...       ...       ...       ...  ...       ...        ...    ...
# 20635  1.5603      25.0  5.045455  ...     39.48    -121.09  0.781
# 20636  2.5568      18.0  6.114035  ...     39.49    -121.21  0.771
# 20637  1.7000      17.0  5.205543  ...     39.43    -121.22  0.923
# 20638  1.8672      18.0  5.329513  ...     39.43    -121.32  0.847
# 20639  2.3886      16.0  5.254717  ...     39.37    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
x=df.drop('price', axis=1)
y=df['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)

# %%
le=LinearRegression()
le.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = le.predict(X_test)
y_pred
# Out:
# array([0.72606026, 1.76744676, 2.71090329, ..., 1.57370312, 1.82742973,
#        2.137662  ])

# %%
# metrics
r=r2_score(y_test,y_pred)
r
# Out:
# 0.5957681720649698

# %%
N=x.shape[0]
P=x.shape[1]
adjr2=1-((1-r)*(N-1)/(N-P-1))
adjr2
# Out:
# 0.5956114247127581

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.5304858998933889

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.5271979237398962
